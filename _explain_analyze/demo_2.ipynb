# %%
import os
import json
from pathlib import Path

from py_pg_explain_analyzer.db import PgConnection
from py_pg_explain_analyzer.analyzer import PgExplainAnalyzer
from py_pg_explain_analyzer.models import AnalysisRequest
from py_pg_explain_analyzer.sql_parser import SqlAnalyzer
from py_pg_explain_analyzer.sql_metadata_extractor import TableInfoExtractor
from openai import OpenAI

# %%
assert False, "Заполни DSN OPENAI_API_KEY"
DSN = "postgresql://user:pass@localhost:5432/dbname"  # строка подключения к Postgres
OPENAI_API_KEY = "sk-...."
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 assert False, "Заполни DSN OPENAI_API_KEY"
#       2 DSN = "postgresql://user:pass@localhost:5432/dbname"  # строка подключения к Postgres
#       3 OPENAI_API_KEY = "sk-...."
#
# AssertionError: Заполни DSN OPENAI_API_KEY

# %%
# DSN = "postgresql://user:pass@localhost:5432/dbname"  # строка подключения к Postgres
# OPENAI_API_KEY = "sk-...."

# %%
# DSN = "postgresql://user:pass@localhost:5432/dbname"  # строка подключения к Postgres
# OPENAI_API_KEY = "sk-...."


# Флаги EXPLAIN (безопасные значения по умолчанию)
ANALYZE = False    # True — выполнит запрос (на свой риск)
VERBOSE = True
BUFFERS = False # работает вместе с ANALYZE
TIMING  = False # работает вместе с ANALYZE
SETTINGS = True
COSTS = True

COLLECT_METADATA = True          # собирать типы/индексы/pg_stats/UNINDEXED
OUT_DIR = "out"                  # папка для артефактов

# Если хочешь брать DSN из окружения — раскомментируй:
# DSN = os.getenv("PG_DSN", DSN)

# ============================================================================

# %%
SQL = """
with found_bad_ads as (select pa.*
                       from ads.ads as aa
                                join parser.ads as pa on pa.item_id = aa.item_id and pa.item_change_at >
                                                                                     aa.item_change_at +
                                                                                     INTERVAL '3 hours 10 minutes'
                                                                                     order by pa.wc_count desc
                                                                                     )

select date(item_change_at), count(*)
from found_bad_ads
group by date(item_change_at)
--order by wc_count desc
;

"""
SQL = SQL.strip()

# %%
# 1) Статический разбор SQL: таблицы/колонки + нормализация + линт
s = SqlAnalyzer(SQL)
tables_and_cols = s.get_tables_and_columns()
normalized_sql = s.normalize()
lints = s.lint()

# %%
# %%time
# 2) (опц.) Метаданные по таблицам и UNINDEXED
metadata = {}
if COLLECT_METADATA:
    try:
        tie = TableInfoExtractor(DSN)
        metadata = tie.analyze(tables_and_cols)
    except Exception as e:
        print(f"[metadata] пропущено из-за ошибки: {e}")
# metadata
# Out:
# CPU times: total: 15.6 ms
# Wall time: 104 ms

# %%
# 3) EXPLAIN FORMAT JSON + эвристики (БЕЗ LLM) → промежуточный результат
db = PgConnection(DSN)
plan_analyzer = PgExplainAnalyzer(db)  # конструктор без llm
req = AnalysisRequest(
    sql=SQL,
    analyze=ANALYZE,
    verbose=VERBOSE,
    buffers=BUFFERS,
    timing=TIMING,
    settings = SETTINGS,
    costs = COSTS,
)
res = plan_analyzer.analyze_one(req)
res
# Out:
# AnalysisResult(sql="with found_bad_ads as (select pa.*\n                       from ads.ads as aa\n                                join parser.ads as pa on pa.item_id = aa.item_id and pa.item_change_at >\n                                                                                     aa.item_change_at +\n                                                                                     INTERVAL '3 hours 10 minutes'\n                                                                                     order by pa.wc_count desc\n                                                                                     )\n\nselect date(item_change_at), count(*)\nfrom found_bad_ads\ngroup by date(item_change_at)\n--order by wc_count desc\n;", plan=Plan(root=PlanNode(node_type='Aggregate', relation_name=None, alias=None, actual_rows=None, plan_rows=5957.0, actual_total_time_ms=None, index_name=None, filter=None, join_type=None, hash_cond=None, merge_cond=None, recheck_cond=None, startup_cost=2538601.52, total_cost=2538675.98, rows=5957.0, width=12, buffers={}, children=[PlanNode(node_type='Subquery Scan', relation_name=None, alias='found_bad_ads', actual_rows=None, plan_rows=1337609.0, actual_total_time_ms=None, index_name=None, filter=None, join_type=None, hash_cond=None, merge_cond=None, recheck_cond=None, startup_cost=2350858.54, total_cost=2531913.48, rows=1337609.0, width=4, buffers={}, children=[PlanNode(node_type='Gather Merge', relation_name=None, alias=None, actual_rows=None, plan_rows=1337609.0, actual_total_time_ms=None, index_name=None, filter=None, join_type=None, hash_cond=None, merge_cond=None, recheck_cond=None, startup_cost=2350858.54, total_cost=2515193.36, rows=1337609.0, width=1477, buffers={}, children=[PlanNode(node_type='Sort', relation_name=None, alias=None, actual_rows=None, plan_rows=191087.0, actual_total_time_ms=None, index_name=None, filter=None, join_type=None, hash_cond=None, merge_cond=None, recheck_cond=None, startup_cost=2349858.42, total_cost=2350336.14, rows=191087.0, width=1477, buffers={}, children=[PlanNode(node_type='Nested Loop', relation_name=None, alias=None, actual_rows=None, plan_rows=191087.0, actual_total_time_ms=None, index_name=None, filter=None, join_type='Inner', hash_cond=None, merge_cond=None, recheck_cond=None, startup_cost=0.43, total_cost=2262930.4, rows=191087.0, width=1477, buffers={}, children=[PlanNode(node_type='Seq Scan', relation_name='ads', alias='pa', actual_rows=None, plan_rows=573262.0, actual_total_time_ms=None, index_name=None, filter=None, join_type=None, hash_cond=None, merge_cond=None, recheck_cond=None, startup_cost=0.0, total_cost=1776093.62, rows=573262.0, width=14, buffers={}, children=[]), PlanNode(node_type='Index Scan', relation_name='ads', alias='aa', actual_rows=None, plan_rows=1.0, actual_total_time_ms=None, index_name='ads_ads_item_id_pk', filter="(pa.item_change_at > (aa.item_change_at + '03:10:00'::interval))", join_type=None, hash_cond=None, merge_cond=None, recheck_cond=None, startup_cost=0.43, total_cost=0.84, rows=1.0, width=12, buffers={}, children=[])])])])])]), planning_time_ms=None, execution_time_ms=None), issues=[Issue(code='SEQSCAN', title='Полное сканирование ads', severity=<Severity.MEDIUM: 'medium'>, details='Запрос делает последовательное сканирование таблицы ads.', node_path='ads'), Issue(code='SORT_NODE', title='Сортировка в плане', severity=<Severity.LOW: 'low'>, details='Используется Sort. Для ORDER BY стоит проверить индекс.', node_path=None)], suggestions=[], index_candidates=[], markdown_report="# Отчёт по анализу запроса\n\n````sql\nwith found_bad_ads as (select pa.*\n                       from ads.ads as aa\n                                join parser.ads as pa on pa.item_id = aa.item_id and pa.item_change_at >\n                                                                                     aa.item_change_at +\n                                                                                     INTERVAL '3 hours 10 min ...

# %%
# 3b) Сбор единого payload для LLM
def _dc_to_dict(obj):
    # быстрая сериализация dataclass объектов (Issue/Suggestion/IndexCandidate)
    try:
        from dataclasses import asdict, is_dataclass
        return asdict(obj) if is_dataclass(obj) else obj
    except Exception:
        return obj.__dict__ if hasattr(obj, "__dict__") else obj

payload = {
    "sql":               SQL,
    "normalized_sql":    normalized_sql,
    "parser_output":     tables_and_cols,           # из SqlAnalyzer
    "metadata":          metadata or {},            # TableInfoExtractor (если включен)
    # "explain_json":      res.raw_explain_json,      # сырой JSON EXPLAIN
    "heuristics": {
        "issues":            [_dc_to_dict(it) for it in res.issues],
        "suggestions":       [_dc_to_dict(s)  for s  in res.suggestions],
        "index_candidates":  [_dc_to_dict(ic) for ic in res.index_candidates],
        # можно добавить «сплющенный» план:
        "plan_meta":         res.plan.model_dump(),  # pydantic → dict
    },
}
payload
# Out:
# {'sql': "with found_bad_ads as (select pa.*\n                       from ads.ads as aa\n                                join parser.ads as pa on pa.item_id = aa.item_id and pa.item_change_at >\n                                                                                     aa.item_change_at +\n                                                                                     INTERVAL '3 hours 10 minutes'\n                                                                                     order by pa.wc_count desc\n                                                                                     )\n\nselect date(item_change_at), count(*)\nfrom found_bad_ads\ngroup by date(item_change_at)\n--order by wc_count desc\n;",
#  'normalized_sql': "WITH found_bad_ads AS (\n  SELECT\n    pa.*\n  FROM ads.ads AS aa\n  JOIN parser.ads AS pa\n    ON pa.item_id = aa.item_id\n    AND pa.item_change_at > aa.item_change_at + INTERVAL '3 hours 10 minutes'\n  ORDER BY\n    pa.wc_count DESC\n)\nSELECT\n  DATE(item_change_at),\n  COUNT(*)\nFROM found_bad_ads\nGROUP BY\n  DATE(item_change_at) /* order by wc_count desc */",
#  'parser_output': {'ads.ads': {'alias': 'aa',
#    'columns': ['item_id', 'item_change_at'],
#    'filter_columns': ['item_id', 'item_change_at']},
#   'parser.ads': {'alias': 'pa',
#    'columns': ['wc_count', 'item_id', 'item_change_at'],
#    'filter_columns': ['item_id', 'item_change_at', 'wc_count']}},
#  'metadata': {'ads.ads': {'columns': [{'column_name': 'item_change_at',
#      'data_type': 'timestamp with time zone'},
#     {'column_name': 'item_id', 'data_type': 'integer'}],
#    'indexes': [{'indexname': 'ads_ads_item_id_pk',
#      'indexdef': 'CREATE UNIQUE INDEX ads_ads_item_id_pk ON ads.ads USING btree (item_id)'},
#     {'indexname': 'ads_ads_item_change_at_index',
#      'indexdef': 'CREATE INDEX ads_ads_item_change_at_index ON ads.ads USING btree (item_change_at)'}],
#    'estimated_rows': 8152442,
#    'columns_stats': {'item_id': {'attname': 'item_id',
#      'n_distinct': -1.0,
#      'null_frac': 0.0,
#      'most_common_vals': None},
#     'item_change_at': {'attname': 'item_change_at',
#      'n_distinct': 1860.0,
#      'null_frac': 0.0,
#      'most_common_vals': '{"2025-07-18 18:08:50+03","2025-08-03 17:43:16+03","2025-07-11 15:26:34+03","2025-07-18 18:19:14+03"}'}},
#    'unindexed_columns': []},
#   'parser.ads': {'columns': [{'column_name': 'item_change_at',
#      'data_type': 'timestamp with time zone'},
#     {'column_name': 'item_id', 'data_type': 'integer'},
#     {'column_name': 'wc_count', 'data_type': 'smallint'}],
#    'indexes': [{'indexname': 'parser_ads_item_id',
#      'indexdef': 'CREATE INDEX parser_ads_item_id ON parser.ads USING btree (item_id)'},
#     {'indexname': 'ads_item_change_at_index',
#      'indexdef': 'CREATE INDEX ads_item_change_at_index ON parser.ads USING btree (item_change_at)'}],
#    'estimated_rows': 4012835,
#    'columns_stats': {'item_id': {'attname': 'item_id',
#      'n_distinct': -1.0,
#      'null_frac': 0.0,
#      'most_common_vals': None},
#     'item_change_at': {'attname': 'item_change_at',
#      'n_distinct': 5957.0,
#      'null_frac': 0.0,
#      'most_common_vals': '{"2025-07-18 21:19:14.799906+03","2025-07-21 12:48:56.405897+03","2025-09-08 12:10:21.055084+03","2025-08-07 19:03:58.893555+03","2025-08-06 15:53:45.571504+03","2025-08-06 16:22:15.45903+03","2025-09-08 11:15:44.723292+03","2025-08-06 14:52:36.860655+03","2025-08-12 00:03:13.632399+03","2025-09-08 10:57:00.927342+03","2025-09-08 11:37:58.080108+03","2025-09-08 11:47:03.894809+03","2025-09-08 11:53:50.337333+03","2025-08-06 17:46:05.538263+03","2025-09-08 11:10:06.417202+03","2025-09-08 11:27:13.103753+03","2025-09-08 11:57:53.493651+03","2025-09-08 17:15:40.278833+03","2025-07-30 14:03:44.044736+03","2025-07-30 14:05:55.075762+03","2025-08-06 15:53:15.278767+03","2025-08-06 16:41:45.230752+03","2025-08-07 11:07:20.755934+03","2025-08-07 18:55:27.909207+03","2025-09-08 11:13:16.609422+03","2025-09-08 11:45:06.234554+03","2025-09-08 11:47:51.495682+03","2025-09-08 11:48:14.832711+03","2025-09-08 11:48:42.960187+03","2025-09-08 12:11:11.626208+03","2025-08-06 14:37:32.692904+03","2025-08-07 11:18:31.923422+03","2025-08-07 14:38:12.451819+03","2025-08-07 20:30:23.002609+03","2025-08-07 21:01:51.372355+03","2025-08-07 21:10:28.987689+03","2025-08-26 06:22:40.085114+03","2025-09-08 11:00:49.557377+03","2025-09-08 11:03:05.012312+03","2025-09-08 11:09:01.313347+03","2025-09-08 11:11:34.179924+03","2025-09-08 11:58:19.075105+03","2025-09-08 12:01:38.056792+03","2025-09-08 12:03:14.745771+03","2025-09-08 12:11:05.978786+03","2025-07-30 14:05:16.810913+03","2025-07-31 18:00:04.320607+03","2025-08-06 14:51:28.912979+03","2025-08-06 15:00:20.59648+03","2025-08-06 16:05:05.090642+03","2025-08-06 17:35:53.146806+03","2025-08-07 13:25:10.479285+03","2025-08-07 18:38:52.970873+03","2025-08-07 18:56:02.376599+03","2025-08-16 14:50:32.743176+03","2025-08-19 19:51:29.723611+03","2025-08-26 06:21:18.475507+03","2025-08-26 06:26:41.142159+03","2025-08-28 09:07:13.616265+03","2025-09-08 10:59:12.70378+03","2025-09-08 11:12:13.038232+03","2025-09-08 11:14:16.851503+03","2025-09-08 11:18:49.589218+03","2025-09-08 11:20:41.363147+03","2025-09-08 11:20:59.019324+03","2025-09-08 11:23:22.16655+03","2025-09-08 11:25:07.222346+03","2025-09-08 11:27:43.151864+03","2025-09-08 11:39:52.605669+03","2025-09-08 11:41:41.566313+03","2025-09-08 11:43:47.839696+03","2025-09-08 11:54:00.461045+03","2025-08-06 14:21:02.921395+03","2025-08-06 14:30:59.629976+03","2025-08-06 15:30:14.977592+03","2025-08-06 16:31:11.003532+03","2025-08-07 11:09:52.716708+03","2025-08-07 11:15:33.227234+03","2025-08-07 11:19:53.889966+03","2025-08-07 11:37:03.527557+03","2025-08-07 14:31:27.207939+03","2025-08-07 14:39:35.911282+03","2025-08-07 15:57:51.003638+03","2025-08-07 19:19:08.582004+03","2025-08-07 20:21:07.982168+03","2025-08-07 20:41:37.482351+03","2025-08-08 06:20:32.75047+03","2025-08-08 10:00:33.512012+03","2025-08-14 01:21:43.806454+03","2025-08-19 19:58:08.517153+03","2025-08-21 02:53:03.163689+03","2025-08-23 16:39:12.784919+03","2025-09-08 10:56:35.112552+03","2025-09-08 11:04:40.390727+03","2025-09-08 11:14:09.996028+03","2025-09-08 11:26:37.560062+03","2025-09-08 11:32:42.715111+03","2025-09-08 11:42:16.975656+03","2025-09-08 11:47:33.244699+03","2025-09-08 11:49:30.961816+03"}'},
#     'wc_count': {'attname': 'wc_count',
#      'n_distinct': 10.0,
#      'null_frac': 0.39602488,
#      'most_common_vals': '{1,2,0,3,4,5}'}},
#    'unindexed_columns': ['wc_count']}},
#  'heuristics': {'issues': [{'code': 'SEQSCAN',
#     'title': 'Полное сканирование ads',
#     'severity': <Severity.MEDIUM: 'medium'>,
#     'details': 'Запрос делает последовательное сканирование таблицы ads.',
#     'node_path': 'ads'},
#    {'code': 'SORT_NODE',
#     'title': 'Сортировка в плане',
#     'severity': <Severity.LOW: 'low'>,
#     'details': 'Используется Sort. Для ORDER BY стоит проверить индекс.',
#     'node_path': None}],
#   'suggestions': [],
#   'index_candidates': [],
#   'plan_meta': {'root': {'node_type': 'Aggregate',
#     'relation_name': None,
#     'alias': None,
#     'actual_rows': None,
#     'plan_rows': 5957.0,
#     'actual_total_time_ms': None,
#     'index_name': None,
#     'filter': None,
#     'join_type': None,
#     'hash_cond': None,
#     'merge_cond': None,
#     'recheck_cond': None,
#     'startup_cost': 2538601.52,
#     'total_cost': 2538675.98,
#     'rows': 5957.0,
#     'width': 12,
#     'buffers': {},
#     'children': [{'node_type': 'Subquery Scan',
#       'relation_name': None,
#       'alias': 'found_bad_ads',
#       'actual_rows': None,
#       'plan_rows': 1337609.0,
#       'actual_total_time_ms': None,
#       'index_name': None,
#       'filter': None,
#       'join_type': None,
#       'hash_cond': None,
#       'merge_cond': None,
#       'recheck_cond': None,
#       'startup_cost': 2350858.54,
#       'total_cost': 2531913.48,
#       'rows': 1337609.0,
#       'width': 4,
#       'buffers': {},
#       'children': [{'node_type': 'Gather Merge',
#         'relation_name': None,
#         'alias': None,
#         'actual_rows': None,
#         'plan_rows': 1337609.0,
#         'actual_total_time_ms': None,
#         'index_name': None,
#         'filter': None,
#         'join_type': None,
#         'hash_cond': None,
#         'merge_cond': None,
#         'recheck_cond': None,
#         'startup_cost': 2350858.54,
#         'total_cost': 2515193.36,
#         'rows': 1337609.0,
#         'width': 1477,
#         'buffers': {},
#         'children': [{'node_type': 'Sort',
#           'relation_name': None,
#           'alias': None,
#           'actual_rows': None,
#           'plan_rows': 191087.0,
#           'actual_total_time_ms': None,
#           'index_name': None,
#           'filter': None,
#           'join_type': None,
#           'hash_cond': None,
#           'merge_cond': None,
#           'recheck_cond': None,
#           'startup_cost': 2349858.42,
#           'total_cost': 2350336.14,
#           'rows': 191087.0,
#           'width': 1477,
#           'buffers': {},
#           'children': [{'node_type': 'Nested Loop',
#             'relation_name': None,
#             'alias': None,
#             'actual_rows': None,
#             'plan_rows': 191087.0,
#             'actual_total_time_ms': None,
#             'index_name': None,
#             'filter': None,
#             'join_type': 'Inner',
#             'hash_cond': None,
#             'merge_cond': None,
#             'recheck_cond': None,
#             'startup_cost': 0.43,
#             'total_cost': 2262930.4,
#             'rows': 191087.0,
#             'width': 1477,
#             'buffers': {},
#             'children': [{'node_type': 'Seq Scan',
#               'relation_name': 'ads',
#               'alias': 'pa',
#               'actual_rows': None,
#               'plan_rows': 573262.0,
#               'actual_total_time_ms': None,
#               'index_name': None,
#               'filter': None,
#               'join_type': None,
#               'hash_cond': None,
#               'merge_cond': None,
#               'recheck_cond': None,
#               'startup_cost': 0.0,
#               'total_cost': 1776093.62,
#               'rows': 573262.0,
#               'width': 14,
#               'buffers': {},
#               'children': []},
#              {'node_type': 'Index Scan',
#               'relation_name': 'ads',
#               'alias': 'aa',
#               'actual_rows': None,
#               'plan_rows': 1.0,
#               'actual_total_time_ms': None,
#               'index_name': 'ads_ads_item_id_pk',
#               'filter': "(pa.item_change_at > (aa.item_change_at + '03:10:00'::interval))",
#               'join_type': None,
#               'hash_cond': None,
#               'merge_cond': None,
#               'recheck_cond': None,
#               'startup_cost': 0.43,
#               'total_cost': 0.84,
#               'rows': 1.0,
#               'width': 12,
#               'buffers': {},
#               'children': []}]}]}]}]}]},
#    'planning_time_ms': None,
#    'execution_time_ms': None}}}

# %%
# 3b) Сбор единого payload для LLM
def _dc_to_dict(obj):
    # быстрая сериализация dataclass объектов (Issue/Suggestion/IndexCandidate)
    try:
        from dataclasses import asdict, is_dataclass
        return asdict(obj) if is_dataclass(obj) else obj
    except Exception:
        return obj.__dict__ if hasattr(obj, "__dict__") else obj

payload = {
    "sql":               SQL,
    "normalized_sql":    normalized_sql,
    "parser_output":     tables_and_cols,           # из SqlAnalyzer
    "metadata":          metadata or {},            # TableInfoExtractor (если включен)
    # "explain_json":      res.raw_explain_json,      # сырой JSON EXPLAIN
    "heuristics": {
        "issues":            [_dc_to_dict(it) for it in res.issues],
        "suggestions":       [_dc_to_dict(s)  for s  in res.suggestions],
        "index_candidates":  [_dc_to_dict(ic) for ic in res.index_candidates],
        # можно добавить «сплющенный» план:
        "plan_meta":         res.plan.model_dump(),  # pydantic → dict
    },  
}
# payload

# %%
# %%time
# 3c) LLM-сводка поверх всех данных (ОПЦИОНАЛЬНО)
llm_result = None
# Пример клиента (раскомментируйте при желании запустить LLM):
from openai import OpenAI
llm_client = OpenAI(api_key=OPENAI_API_KEY)
from py_pg_explain_analyzer.llm_summarizer import run_llm
llm_result = run_llm(llm_client, payload)
# Out:
# CPU times: total: 969 ms
# Wall time: 9.97 s

# %%
llm_result, normalized_sql
# Out:
# ({'problems': [{'title': 'Полное сканирование таблицы parser.ads',
#     'severity': 'medium',
#     'details': 'В плане запроса обнаружено последовательное сканирование таблицы parser.ads (alias pa), что может приводить к высокой нагрузке при большом объеме данных (около 4 млн строк).'},
#    {'title': 'Сортировка в подзапросе с ORDER BY',
#     'severity': 'low',
#     'details': 'В CTE found_bad_ads используется ORDER BY pa.wc_count DESC, но отсутствует индекс по wc_count, что приводит к дополнительной сортировке в памяти.'}],
#   'warnings': [{'title': 'Отсутствие индекса по wc_count',
#     'details': 'Колонка wc_count в таблице parser.ads не индексирована, что ухудшает производительность сортировки по ней.'}],
#   'recommendations': [{'title': 'Добавить составной индекс для ускорения соединения и фильтрации',
#     'actions': [{'sql': 'CREATE INDEX ON parser.ads (item_id, item_change_at);',
#       'note': 'Индекс поможет ускорить соединение по item_id и фильтрацию по item_change_at > aa.item_change_at + интервал.'}]},
#    {'title': 'Добавить индекс по wc_count для ускорения сортировки',
#     'actions': [{'sql': 'CREATE INDEX ON parser.ads (wc_count DESC);',
#       'note': 'Индекс позволит избежать сортировки в памяти при ORDER BY pa.wc_count DESC в CTE.'}]},
#    {'title': 'Пересмотреть необходимость ORDER BY в CTE',
#     'actions': [{'sql': None,
#       'note': 'Если ORDER BY в CTE не влияет на итоговый результат (т.к. итоговый запрос не использует порядок), его можно убрать для оптимизации.'}]}],
#   'fixed_sql': None},
#  "WITH found_bad_ads AS (\n  SELECT\n    pa.*\n  FROM ads.ads AS aa\n  JOIN parser.ads AS pa\n    ON pa.item_id = aa.item_id\n    AND pa.item_change_at > aa.item_change_at + INTERVAL '3 hours 10 minutes'\n  ORDER BY\n    pa.wc_count DESC\n)\nSELECT\n  DATE(item_change_at),\n  COUNT(*)\nFROM found_bad_ads\nGROUP BY\n  DATE(item_change_at) /* order by wc_count desc */")
